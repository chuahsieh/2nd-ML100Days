# %% [markdown]
# # D1
# ## 作業1
# dataset:Google Play Store Apps (https://www.kaggle.com/lava18/google-play-store-apps)
# 1. 你選的這組資料為何重要?
# 裡面提供了在Google Play Store上的各種app資料，包含價錢、下載次數、app類型與瀏覽次數等，要是能分析出這個資料哪些會影響到下載次數的話，就可以知道哪種app是比較熱門的，或是哪些資料會影響到使用者的評價，如此一來就能對自己已開發的app進行改進或是了解目前的市場趨勢進行開發。
#
# 2. 資料從何而來?(tips: 譬如提供者是誰、以什麼方式蒐集)
# 資料提供者為Lavanya Gupta分享於Kaggle上，在Google Play Store上爬蟲蒐集而來。
#
# 3. 蒐集而來的資料型態為何
# 結構化資料，欄位如下：
#  - Category：app類型
#  - Rating：使用者評價
#  - Reviews：瀏覽次數
#  - Size：檔案大小
#  - Installs：下載次數
#  - Type：付費類型（免費／收費）
#  - Price：價格（若為免費app即為0）
#  - Content Rating：用戶族群
#  - Last Updated：最後一次更新日期
#  - Current Ver：目前版本
#  - Android Ver：支援Android版本
#
# 4. 這組資料想解決的問題如何評估
# 觀察哪些因素會影響到下載量與瀏覽次數
#
# ## 作業2
# ### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 假設載客地點及時間與業績呈正相關
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 載到客人時，自動記錄地點與時間
# 3. 蒐集而來的資料型態為何
# location:上車地點
# datetime:時間
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 觀察上車地點、時間與業績之間的關係
#
# ## 作業3

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_square_error(y, yp):
    mse = MSE = sum((y - yp) ** 2) / len(y)
    return mse
def mean_absolute_error(y, yp):
    """
    MAE計算
    y = 實際值
    yp = 預測值
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have points.")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points(And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MAE = mean_absolute_error(y, y_hat)
MSE = mean_square_error(y, y_hat)
print("the mean absolute error is %3f" % (MAE))
print("the mean square error is %3f" % (MSE))
# Out:
# the mean absolute error is 10.648351
# the mean square error is 180.975137
